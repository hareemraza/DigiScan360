# %%
import random
from faker import Faker
from datetime import datetime, timedelta
import csv

fake = Faker()

def generate_message(brand):
    messages=[
        f"Immerse yourself in pure sound bliss with our latest {brand} headphones! 🎶✨",
        f"Experience music like never before with the unparalleled sound quality of {brand} headphones. Upgrade your listening experience today! 🎧🔥",
        f"Tired of tangled cords? Cut the cord with our wireless {brand} headphones and enjoy freedom of movement without compromising on sound quality. 🚀",
        f"Calling all audiophiles! Elevate your audio game with the premium craftsmanship and superior sound of {brand} headphones. Your ears deserve the best! 🎵💫",
        f"Make every beat count with {brand} headphones. From deep bass to crisp highs, we've got your music covered. Tap into the ultimate audio experience now! 🎶😎",
        f"Unleash the power of music with {brand} headphones. Whether you're working out or winding down, let our headphones be your soundtrack to life. 🎵💪",
        f"Life's too short for mediocre sound. Upgrade to {brand} headphones and discover the true essence of your favorite tunes. Your ears will thank you! 🎧❤️",
        f"Get lost in the music with {brand} headphones. Precision engineering meets unmatched comfort for an audio experience like no other. Dive in and feel the difference! 🎶😌",
        f"Quality you can hear, comfort you can feel. Discover the perfect harmony of performance and design with {brand} headphones. Your ears deserve nothing but the best! 🎧✨",
        f"Step up your audio game with {brand} headphones. Whether you're a music lover, gamer, or podcast enthusiast, we've got the perfect pair for you. Explore our range now! 🎶🎮",
        f"Experience the magic of superior sound with {brand} headphones. Elevate your listening experience to new heights and indulge in every note with pristine clarity. 🎵✨",
        f"Transform your everyday moments into extraordinary experiences with {brand} headphones. Let the music take you on a journey and escape into your own world of sound. 🎧🌟",
        f"Discover the perfect balance of style and substance with {brand} headphones. Designed to turn heads and deliver exceptional audio performance, they're a statement accessory for music enthusiasts. 🎶💼",
        f"Upgrade your gaming setup with {brand} headphones and immerse yourself in the action like never before. Hear every footstep, explosion, and dialogue with crystal-clear precision. 🎮🔊",
        f"Unwind after a long day and unwind with {brand} headphones. Let the soothing sounds of your favorite playlist transport you to a place of relaxation and tranquility. 🎶😌",
        f"Experience true versatility with {brand} headphones. Whether you're on a call, listening to music, or watching movies, our headphones deliver exceptional performance in every scenario. 🎧📞",
        f"Elevate your productivity and focus with {brand} headphones. Block out distractions and dive into your work with immersive sound quality and noise-canceling technology. 🎵💻",
        f"Make a bold statement with {brand} headphones. With sleek designs and premium finishes, our headphones are as fashionable as they are functional. Stand out from the crowd and express your style. 🎧👌",
        f"Experience the thrill of live concerts from the comfort of your home with {brand} headphones. Feel like you're front row at every show with our unparalleled sound reproduction. 🎶🏠",
        f"Embark on a journey of sonic discovery with {brand} headphones. Rediscover your favorite tracks and uncover hidden nuances in your music library with our studio-quality sound. 🎧🔍",
        f"Take your workouts to the next level with {brand} headphones. Sweat-proof, secure fit, and motivating sound - the perfect companions for your fitness journey. 🎶💪",
        f"Experience the future of audio technology with {brand} headphones. From advanced noise cancellation to seamless connectivity, we're redefining what it means to listen. 🎧🔊",
        f"Join the revolution in wireless audio with {brand} headphones. Say goodbye to tangled wires and hello to freedom of movement without compromise. 🚀🎵",
        f"Unlock the full potential of your music library with {brand} headphones. Our premium sound signature ensures that every track is heard exactly as the artist intended. 🎶🔓",
        f"Discover a world of sound with {brand} headphones. Whether you're a casual listener or a seasoned audiophile, our headphones deliver an unrivaled listening experience. 🎧🌍",
        f"Enhance your gaming experience with {brand} headphones. From immersive surround sound to clear communication, our headphones give you the competitive edge you need. 🎮🎧",
        f"Stay connected and entertained on the go with {brand} headphones. With long-lasting battery life and intuitive controls, you can enjoy your favorite music wherever life takes you. 🎶🚗",
        f"Indulge in luxury audio with {brand} headphones. Crafted from premium materials and engineered for perfection, our headphones are a testament to uncompromising quality. 🎧💎",
        f"Experience the magic of live performances with {brand} headphones. Our immersive soundstage and dynamic drivers bring the concert hall to you, no matter where you are. 🎵🎤",
        f"Ignite your passion for music with {brand} headphones. Whether you're a casual listener or a dedicated audiophile, our headphones are designed to inspire and delight. 🎧❤️",
        f"Sumérgete en el mundo del sonido con los auriculares {brand}. Descubre cada matiz y detalle de tu música favorita como nunca antes. 🎶✨",
        f"Experimenta la magia del sonido superior con los auriculares {brand}. Eleva tu experiencia auditiva a nuevas alturas y sumérgete en cada nota con una claridad cristalina. 🎵✨",
        f"Transforma tus momentos cotidianos en experiencias extraordinarias con los auriculares {brand}. Deja que la música te lleve en un viaje y escapa a tu propio mundo de sonido. 🎧🌟",
        f"Descubre el equilibrio perfecto entre estilo y calidad con los auriculares {brand}. Diseñados para llamar la atención y ofrecer un rendimiento de audio excepcional, son un accesorio de declaración para los entusiastas de la música. 🎶💼",
        f"Actualiza tu configuración de juego con los auriculares {brand} y sumérgete en la acción como nunca antes. Escucha cada paso, explosión y diálogo con una precisión cristalina. 🎮🔊",
        f"Relájate después de un largo día con los auriculares {brand}. Deja que los sonidos relajantes de tu lista de reproducción favorita te transporten a un lugar de relajación y tranquilidad. 🎶😌",
        f"Experimenta la verdadera versatilidad con los auriculares {brand}. Ya sea en una llamada, escuchando música o viendo películas, nuestros auriculares ofrecen un rendimiento excepcional en cualquier situación. 🎵💻",
        f"Haz una declaración audaz con los auriculares {brand}. Con diseños elegantes y acabados premium, nuestros auriculares son tan elegantes como funcionales. Destaca entre la multitud y expresa tu estilo. 🎧👌",
        f"Embárcate en un viaje de descubrimiento sonoro con los auriculares {brand}. Redescubre tus pistas favoritas y descubre matices ocultos en tu biblioteca musical con nuestro sonido de calidad de estudio. 🎧🔍",
        f"Eleva tus entrenamientos con los auriculares {brand}. Resistentes al sudor, ajuste seguro y sonido motivador: los compañeros perfectos para tu viaje de fitness. 🎶💪",
        f"Descubre la revolución en tecnología de audio con los auriculares {brand}. Desde la cancelación avanzada de ruido hasta la conectividad perfecta, estamos redefiniendo lo que significa escuchar. 🎧🔊",
        f"Libérate de los cables con los auriculares inalámbricos {brand}. Disfruta de la libertad de movimiento sin comprometer la calidad del sonido. 🚀🎶",
        f"Explora un mundo de sonido con los auriculares {brand}. Ya seas un oyente casual o un audiófilo experimentado, nuestros auriculares ofrecen una experiencia auditiva incomparable. 🎧🌍",
        f"Mejora tu experiencia de juego con los auriculares {brand}. Desde un sonido envolvente inmersivo hasta una comunicación clara, nuestros auriculares te dan la ventaja competitiva que necesitas. 🎮🎧",
        f"Mantente conectado y entretenido en movimiento con los auriculares {brand}. Con una batería de larga duración y controles intuitivos, puedes disfrutar de tu música favorita dondequiera que vayas. 🎶🚗",
        f"Indulge en el lujo del audio con los auriculares {brand}. Fabricados con materiales premium y diseñados para la perfección, son un testimonio de calidad intransigente. 🎧💎",
        f"Experimenta la magia de los conciertos en vivo con los auriculares {brand}. Nuestra etapa de sonido inmersiva y drivers dinámicos traen la sala de conciertos a tu hogar, estés donde estés. 🎵🎤",
        f"Ignite tu pasión por la música con los auriculares {brand}. Ya seas un oyente casual o un audiófilo dedicado, nuestros auriculares están diseñados para inspirar y deleitar. 🎧❤️",
        f"Optimiza tu productividad y concentración con los auriculares {brand}. Bloquea las distracciones y sumérgete en tu trabajo con tecnología de cancelación de ruido y rendimiento de audio incomparables. 🎵💼",
        f"Actualiza tu estilo de vida con los auriculares {brand}. Desde el diseño elegante hasta la calidad de audio superior, nuestros auriculares complementan tu estilo de vida moderno con un toque de elegancia. 🎧👑"]

    return random.choice(messages)


def generate_comment(brand):
    comments = [
        f"Love my new {brand} headphones! The sound quality is amazing.",
        f"Just got my hands on the {brand} headphones. They're fantastic!",
        f"Not really impressed with the {brand} headphones. Expected better.",
        f"The battery life on these {brand} headphones is disappointing.",
        f"Anyone else experiencing connectivity issues with their {brand} headphones?",
        f"Thinking about getting the {brand} headphones. Any thoughts or reviews?",
        f"The noise cancellation on these {brand} headphones is top-notch!",
        f"I've had my {brand} headphones for a while now and they're still going strong!",
        f"Looking for recommendations for a good case for {brand} headphones.",
        f"Received the {brand} headphones as a gift. Pleasantly surprised!",
        f"Are the {brand} headphones worth the hype? Considering buying a pair.",
        f"Can't seem to find replacement ear cushions for my {brand} headphones. Any suggestions?",
        f"Just customized the sound settings on my {brand} headphones. Game changer!",
        f"I've tried several brands, but the {brand} headphones are definitely my favorite!",
        f"Experiencing some discomfort wearing the {brand} headphones for long periods. Any tips?",
        f"The {brand} headphones have exceeded my expectations. Highly recommend!",
        f"Absolutely loving the sound quality of my new {brand} headphones! It's like rediscovering my favorite songs all over again.",
        f"Just got my hands on the {brand} headphones and they're a game-changer for my daily commute. The noise cancellation is top-notch!",
        f"The bass on these {brand} headphones is incredible! Perfect for pumping up my workout playlist.",
        f"Disappointed with the durability of my {brand} headphones. They broke after just a few months of use.",
        f"Can't get enough of the sleek design of my {brand} headphones. They look as good as they sound!",
        f"Had high hopes for the {brand} headphones, but they fell short on comfort. Not ideal for long listening sessions.",
        f"Impressed with the battery life of my {brand} headphones. They last all day without needing a recharge.",
        f"Just discovered the EQ settings on my {brand} headphones and now I can customize the sound exactly to my liking. So cool!",
        f"The wireless connectivity of the {brand} headphones makes listening to music on the go so much easier. No more tangled cords!",
        f"Anyone else experiencing issues with the Bluetooth connection on their {brand} headphones? Mine keep disconnecting randomly.",
        f"¡Me encanta la calidad de sonido de mis nuevos auriculares {brand}! Es como redescubrir mis canciones favoritas una y otra vez.",
        f"Acabo de conseguir los auriculares {brand} y son un cambio de juego para mi viaje diario. La cancelación de ruido es excelente.",
        f"¡El bajo en estos auriculares {brand} es increíble! Perfecto para animar mi lista de reproducción de entrenamiento.",
        f"Decepcionado con la durabilidad de mis auriculares {brand}. Se rompieron después de solo unos meses de uso.",
        f"¡No puedo tener suficiente del diseño elegante de mis auriculares {brand}! Se ven tan bien como suenan.",
        f"Tenía grandes esperanzas para los auriculares {brand}, pero fallaron en comodidad. No son ideales para largas sesiones de escucha.",
        f"Impresionado con la duración de la batería de mis auriculares {brand}. ¡Durante todo el día sin necesidad de recargar!",
        f"Acabo de descubrir los ajustes de ecualización en mis auriculares {brand} y ahora puedo personalizar el sonido exactamente a mi gusto. ¡Genial!",
        f"La conectividad inalámbrica de los auriculares {brand} hace que escuchar música sobre la marcha sea mucho más fácil. ¡Sin enredos de cables!",
        f"¿Alguien más está experimentando problemas con la conexión Bluetooth en sus auriculares {brand}? Los míos se desconectan aleatoriamente.",
        f"Los auriculares {brand} son imprescindibles para mis largas sesiones de estudio. El aislamiento de ruido ayuda a concentrarme mejor.",
        f"No puedo resistirme a la comodidad de mis auriculares {brand}. Son ligeros y se ajustan perfectamente.",
        f"Los graves profundos de los auriculares {brand} hacen que cada canción suene épica. ¡Una experiencia de audio inigualable!",
        f"Mis auriculares {brand} son como una extensión de mí mismo. Los llevo a todas partes y nunca me decepcionan.",
        f"¿Alguien más ha notado un zumbido extraño en los auriculares {brand}? Me pregunto si es un problema común.",
        f"La cancelación de ruido en los auriculares {brand} es una bendición cuando viajo. ¡Puedo sumergirme en mi música sin distracciones!",
        f"Nunca me arrepentiré de invertir en mis auriculares {brand}. La calidad de construcción y el sonido son simplemente incomparables.",
        f"Cada vez que escucho música con mis auriculares {brand}, descubro nuevos matices en las canciones. ¡Una experiencia auditiva enriquecedora!",
        f"Los auriculares {brand} me han ayudado a descubrir una nueva pasión por la música. ¡Cada nota suena más clara y vibrante!",
        f"Los auriculares {brand} son perfectos para sesiones de juego inmersivas. ¡El sonido envolvente te sumerge por completo en el juego!",
        f"Estoy impresionado por la duración de la batería de mis auriculares {brand}. Puedo usarlos durante horas sin preocuparme por recargarlos.",
        f"Los auriculares {brand} son mi compañero de entrenamiento imprescindible. La resistencia al sudor los hace perfectos para mis sesiones de ejercicio.",
        f"No puedo imaginar mi vida diaria sin mis auriculares {brand}. Se han convertido en una parte esencial de mi rutina diaria.",
        f"Los auriculares {brand} son mi escape del mundo exterior. Cuando los uso, puedo sumergirme por completo en mi propia burbuja de sonido.",
        f"Mis auriculares {brand} son una obra maestra de ingeniería de audio. Cada componente está diseñado para ofrecer la mejor experiencia auditiva posible.",
        f"My {brand} headphones are like a symphony in my ears, every note crystal clear.",
        f"Just unboxed my {brand} headphones and they're sleeker than I imagined!",
        f"The noise isolation on these {brand} headphones is so good, I could be in my own world.",
        f"My {brand} headphones are my daily companion, from workouts to work calls, they never disappoint.",
        f"Exploring new genres with my {brand} headphones, every beat feels like a revelation.",
        f"Finally found the perfect fit with my {brand} headphones, comfort and style in one.",
        f"No more hassle with cords, the wireless feature on my {brand} headphones is a game-changer.",
        f"Late-night gaming sessions just got better with my {brand} headphones, immersive sound all the way.",
        f"The sleek design of my {brand} headphones turns heads everywhere I go.",
        f"Binge-watching my favorite shows with my {brand} headphones, it's like being in a theater."

    ]
    return random.choice(comments)


locations = [
    "Madrid", "Barcelona", "Valencia", "Sevilla", "Málaga", "Bilbao", "Zaragoza", "Murcia", "Las Palmas", "Palma",
    "Santa Cruz", "Alicante", "Córdoba", "Valladolid", "Vigo", "Gijón", "Vitoria-Gasteiz", "A Coruña", "Elche",
    "Granada", "Badalona", "Tarrasa", "Petrel", "Sabadell", "Cartagena", "Oviedo", "Jerez de la Frontera", "Móstoles",
    "Pamplona", "Almería", "Alcalá de Henares", "Leganés", "Donostia", "Fuenlabrada", "Getafe", "Castellón de la Plana",
    "Burgos", "Albacete", "Santander", "Alcorcón", "Guadalajara", "La Laguna", "Marbella", "Logroño", "Badajoz",
    "Salamanca", "Lleida", "Huelva", "Dos Hermanas", "Tarragona", "Parla", "Mataró", "Torrejón de Ardoz", "Algeciras",
    "León", "Alcobendas", "Jaén", "Cádiz", "Reus", "Roquetas de Mar", "Girona", "Ourense", "Telde", "San Vicente de Baracaldo",
    "Vaciamadrid", "Santiago de Compostela", "Las Rozas de Madrid", "San Cugat del Vallés", "San Fernando",
    "San Sebastián de los Reyes", "Torrevieja", "Torrente", "Ciudad de Melilla", "Toledo", "Fuengirola", "Arona",
    "San Baudilio de Llobregat", "Ciudad de Ceuta", "Valdemoro", "Rubí", "Manresa", "Gandía", "Benalmádena", "Avilés",
    "Paterna", "Majadahonda", "Benidorm", "Torremolinos", "Castelldefels", "Villanueva y Geltrú", "Viladecáns",
    "Collado-Villalba", "El Prat de Llobregat", "Arrecife", "La Línea de la Concepción", "Granollers", "Irún",
    "Boadilla del Monte", "San Vicente del Raspeig", "Mérida", "Elda", "Ibiza", "Mollet", "Torrelavega",
    "Rincón de la Victoria", "Figueras", "Gavá", "Vich", "Mairena del Aljarafe", "Esplugas de Llobregat",
    "Santurce-Antiguo", "San Felíu de Llobregat", "Mislata", "Portugalete", "Alcantarilla", "Blanes", "Igualada",
    "Villafranca del Panadés", "Burjasot", "Santander", "Alcázares", "San Juan Despí", "Aldaya", "Salt",
    "Manises", "Calafell", "Salou", "Alacuás", "Durango", "Catarroja", "Premiá de Mar", "Martorell", "Camas",
    "San Vicente dels Horts", "Sestao", "San Pedro del Pinatar", "Paiporta", "San Andrés de la Barca",
    "Molíns de Rey", "Santa Perpetua de Moguda", "Calpe", "Alboraya", "Tomares", "San Juan de Alicante", "Torrelodones",
    "Armilla", "Olesa de Montserrat", "Erandio", "Mejorada del Campo", "Vilaseca de Solcina", "Zarautz", "Bormujos",
    "San Felíu de Guixols", "San Juan de Aznalfar",
     "Maracena", "Moncada", "Alfafar", "Manlleu", "San Juan de Vilasar", "Palafrugell", "Puzol", "Bañolas",
    "Sant Just Desvern", "Archena", "Calella", "Humanes de Madrid", "Barañáin", "Malgrat de Mar", "La Corredoría",
    "Cardedeu", "Utebo", "El Astillero", "Palamós", "Torredembarra", "Castilleja de la Cuesta", "Canovellas",
    "Guernica y Luno", "Albal", "Cubellas", "Montornés del Vallés", "Masamagrell", "Churriana de la Vega",
    "Arenys de Mar", "Aguadulce", "Benetúser", "Ermúa", "Cunit", "Mollerusa", "Canet de Mar", "Alpedrete",
    "Torelló", "Sopelana", "Ogíjares", "Cuarte de Huerva", "Santa Marta de Tormes", "Gines", "La Llagosta",
    "Godella", "Velilla de San Antonio", "Vilanova del Camí", "Ceuti", "Mongat", "Huétor Vega",
    "San Andrés de Llevaneras", "Picaña", "Pallejá", "Peligros", "Beniel", "Berriozar", "Meliana", "Sedaví",
    "Gelves", "Garrucha", "Masanasa", "Alella", "Torrejón de la Calzada", "Tabernes Blanques", "Tiana", "Montmeló",
    "Reinosa", "Colindres", "Santiponce", "Ortuella", "Santa Coloma de Cervelló", "Puebla de Farnals", "Ondárroa",
    "Cabrils", "Cúllar-Vega", "Foyos", "Rocafort", "Almácera", "Bigastro", "Canet de Berenguer", "Lekeitio",
    "Castellar y Oliveral", "Villanueva del Ariscal", "Teyá", "Roda del Ter", "Nazaret", "Navarcles", "Tanos",
    "Cájar", "Capellades", "Sarriá de Ter", "Bellreguart", "Rafal", "Formentera de Segura", "Hostalrich",
    "Albuixech", "Jun", "Sierrapando", "Bonrepós y Mirambell", "San Hipólito de Voltregá", "Vinalesa", "Alfara del Patriarca",
    "Caldas de Estrach", "San Andrés", "Miramar", "Castilleja de Guzmán", "Barreda", "Masalfasar", "Almoines",
    "Benisanó", "Molnás", "Varea", "El Saler", "Fuente de San Luis", "El Perelló", "Benirredrá", "Ganzo", "Benzú",
    "Carpesa", "El Puente del Arzobispo", "Igueldo", "Palmera", "Hortaleza", "Torres",
     "Paris",
    "Rome",
    "London",
    "Berlin",
    "New York City",
    "Tokyo",
    "Sydney",
    "Moscow",
    "Beijing",
    "Dubai",
    "Toronto",
    "Rio de Janeiro",
    "Cape Town",
    "Buenos Aires",
    "Istanbul"
]



class Page:
    def __init__(self, id,contact_address, current_location, emails, fan_count, followers_count, name, username, verified):
        self.id = id
        self.name = name
        self.fan_count = fan_count
        self.followers_count = followers_count
        self.username = username
        self.verified = verified
        self.published_posts = []
        self.contact_address= contact_address
        self.current_location= current_location
        self.emails=emails

class Comment:
    def __init__(self, comment_id, comment_created_time, comment_from, comment_like_count, comment_message):
        self.comment_id = comment_id
        self.comment_created_time = comment_created_time
        self.comment_from = comment_from
        self.comment_like_count = comment_like_count
        self.comment_message = comment_message

class Post:
    def __init__(self, id, created_time, message, shares, comments, likes, reactions):
        self.id = id
        self.created_time = created_time
        self.message = message
        self.shares = shares
        self.comments = comments
        self.likes = likes
        self.reactions = reactions

class User:
    def __init__(self, id, name):
        self.id = id
        self.name = name

def generate_random_datetime(start_date, end_date):
    delta = end_date - start_date
    random_seconds = random.randint(0, int(delta.total_seconds()))
    return start_date + timedelta(seconds=random_seconds)

def generate_random_datetime(start_date, end_date=None):
    if end_date is None:
        end_date = datetime.now()
    delta = end_date - start_date
    random_seconds = random.randint(0, int(delta.total_seconds()))
    return start_date + timedelta(seconds=random_seconds)

def generate_random_datetime(start_date, end_date=None):
    if end_date is None:
        end_date = datetime.now()
    delta = end_date - start_date
    random_seconds = random.randint(0, int(delta.total_seconds()))
    return start_date + timedelta(seconds=random_seconds)

# Modify the function generate_synthetic_data(num_pages, num_posts_per_page, num_comments_per_post)
def generate_synthetic_data(min_pages, max_pages, min_posts_per_page, max_posts_per_page, min_comments_per_post, max_comments_per_post):
    brands = ['JBL', 'Bose', 'Sony', 'Phillips', 'TOZO', 'AKG', 'Logitech', 'Apple', 'Xiaomi', 'oneodio', 'Sennheiser',
          'Audio-Technica', 'Skullcandy', 'Sennsis', 'Master & Dynamic', 'Panasonic', 'Bang & Olufsen', 'V-MODA', 
          'Koss', 'Focal', 'Pioneer', 'Denon','House of Marley', 'Audeze', 'Beats by Dre', 'Grado', 
          'Beyerdynamic', 'Shure', 'Razer', 'Marshall', 'Bowers & Wilkins']
    verified_brands = ['JBL', 'Bose', 'Sony', 'Phillips', 'TOZO', 'AKG', 'Logitech', 'Apple', 'Xiaomi',
          'Skullcandy', 'Sennsis', 'Master & Dynamic', 'Panasonic', 'Bang & Olufsen', 'V-MODA', 
          'Koss', 'Focal', 'Pioneer', 'Denon','House of Marley', 'Audeze', 'Beats by Dre', 'Grado', 
          'Beyerdynamic', 'Shure', 'Razer', 'Marshall', 'Bowers & Wilkins']  # List of verified brands
    
    num_pages = random.randint(min_pages, max_pages)

    data = []

    for i in range(num_pages):
        page_id =f"page_{i}"
        contact_address= fake.phone_number() if random.choice([True, False]) else fake.email()
        current_location= random.choice(locations) if random.random() < 0.90 else "null"
        emails= [fake.email() for _ in range(random.randint(1, 3))]
        name = random.choice(brands)
        fan_count = random.randint(500, 50000) if name in verified_brands else random.randint(100, 10000)
        followers_count = random.randint(500, 50000) if name in verified_brands else random.randint(100, 10000)
        username = name + "audio"
        verified = True if name in verified_brands else False
        page = Page(page_id, contact_address, current_location, emails, fan_count, followers_count, name, username, verified)

        num_posts_per_page = random.randint(min_posts_per_page, max_posts_per_page)

        for j in range(num_posts_per_page):
            brand1 = random.choice(brands)
            post_id = f"{page_id}_post_{j}"
            created_time = generate_random_datetime(datetime(2022, 1, 1))
            message = generate_message(brand1) 
            comments=[]
            shares = random.randint(0, 100) if random.random() < 0.95 else "null"
            likes = [User(f"user_{random.randint(1, 1000)}", f"User {random.randint(1, 1000)}") for _ in range(random.randint(0, 100))]
            reactions = [User(f"user_{random.randint(1, 1000)}", f"User {random.randint(1, 1000)}") for _ in range(random.randint(0, 100))]
            post = Post(post_id, created_time, message, shares, comments, likes, reactions)

            num_comments_per_post = random.randint(min_comments_per_post, max_comments_per_post)

            for k in range(num_comments_per_post):
                brand2 = random.choice(brands) if random.random() < 0.95 else "null"
                comment_id = f"{post_id}_comment_{k}"
                comment_created_time = generate_random_datetime(created_time)
                comment_from = fake.user_name() if random.random() < 0.95 else None
                comment_like_count = random.randint(0, 50)
                comment_message = generate_comment(brand2) if random.random() < 0.95 else "null"
                comment = Comment(comment_id, comment_created_time, comment_from, comment_like_count, comment_message)
                post.comments.append(comment)

            page.published_posts.append(post)

        data.append(page)

    return data


# Example usage:
pages_data = generate_synthetic_data(10, 20, 100, 200, 200, 300)


# Save to CSV with verified column
def save_to_csv(data, filename):
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        # Write header
        writer.writerow(["id", "contact_address", "current_location", "emails", "fan_count", "followers_count", 
                         "name", "username", "post_id", "created_time", "message", "shares", "likes", "reactions", 
                         "comment_id", "created_time", "from", "like_count", "comment", "verified"])

        # Write data
        for page in data:
            for post in page.published_posts:
                for comment in post.comments:
                    writer.writerow([
                        page.id, page.contact_address, page.current_location,page.emails, page.fan_count, page.followers_count, page.name, page.username, 
                        post.id, post.created_time, post.message, 
                        post.shares, len(post.likes), len(post.reactions), 
                        comment.comment_id, comment.comment_created_time,comment.comment_from, comment.comment_like_count, comment.comment_message,
                        page.verified
                    ])

save_to_csv(pages_data, 'facebook_data.csv')
